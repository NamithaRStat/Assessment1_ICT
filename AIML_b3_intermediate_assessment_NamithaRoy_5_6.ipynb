# %% [markdown]
# <a href="https://colab.research.google.com/github/NamithaRStat/Assessment1_ICT/blob/main/AIML_b3_intermediate_assessment_NamithaRoy_5_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intermediate Python Assessment
#
# Welcome to the assessment!
# This notebook contains 3 challenges. Please read the instructions carefully and complete each task in the provided code cells.
#
#
# **Rules:**
# - Do not change function names or signatures.
# - Write clean, well-documented code.
# - Run all cells before submission.

# %% [markdown]
# ## Challenge 1: Word Frequency Analyzer
# Write a function `top_k_words(filename: str, k: int) -> list` that returns the top k frequent words.
# - Ignore case and punctuation.
# - Sort by frequency, then alphabetically.

# %%
import re
from collections import Counter

def top_k_words(filename: str, k: int) -> list:
    pass

# Sample Test (create a sample file)
with open("sample.txt", "w") as f:
    f.write("Data science is evolving. Python is versatile. Learning never stops.")

print(top_k_words("sample.txt", 3))  #expected ["is", "data", "science"]
# Out:
# None

# %% [markdown]
# ## Challenge 2 : Analyze daily expenses and extract insights.
# User enters:
#
# Number of transactions
# Category and amount
#
# Food 200
# Travel 500
# Food 300
# Shopping 700
#
# ### Output
# * Total expense
# * Highest expense category
# * Category-wise total

# %%
def analyze_expenses():
    n = int(input("Enter number of transactions: "))

    expenses = {}

    for _ in range(n):
        category, amount = input().split()
        amount = float(amount)

        #store category-wise total
        expenses = group_by(category).sum(amount)
    # TODO: calculate total expense
    tot_exp = sum(ctgry_tot)
    # TODO: find highest category
    highest_category = max(ctgry_tot)
    print("Total Expense:", total)
    print("Highest Category:", highest_category)
    print("Category-wise:", expenses)

analyze_expenses()
# Out:
# Enter number of transactions: 1
# Food
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1763/2941399716.py in <cell line: 0>()
#      18     print("Category-wise:", expenses)
#      19
# ---> 20 analyze_expenses()
#
# /tmp/ipykernel_1763/2941399716.py in analyze_expenses()
#       5
#       6     for _ in range(n):
# ----> 7         category, amount = input().split()
#       8         amount = float(amount)
#       9
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# ### Challenge 3: Data Cleaner (Mini Pandas Logic Without Pandas)
#
# 10 ,20 ,abc ,30 ,-5 , 40
#
# * Remove invalid values
# * Remove negative values
#
#
# Show:
# * Clean list
# * Average
# * Max value

# %%
def clean_data():
    n = int(input("Enter number of values: "))

    data = []

    for _ in range(n):
        value = input()

        try:
            num = float(value)

            # TODO: ignore negative values
             data.remove('-5')
            data.append(num)

        except:
            n.remove('abc')
            pass

    # TODO: calculate average
      avg = mean(n)
    # TODO: find max
       max_val = max(n)
    print("Clean Data:", data)
    print("Average:", avg)
    print("Max:", max_val)

clean_data()
# Out:
#   File "<tokenize>", line 21
#     avg = mean(n)
#     ^
# IndentationError: unindent does not match any outer indentation level
